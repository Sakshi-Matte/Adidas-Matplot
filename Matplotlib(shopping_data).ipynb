# %%
# cutomer shoppimng
# gender age category,pay method,
# consider u need to open a shop in which mall i should open ,and which category i should open , and whuch gebder i should target and what price range to keep
#graph interpretation

# addidas
# which prod is having max nd min sales 
#prod and operating profit
#state and sales
#state and product

# trainrf
# data set of mobile
# compare all features  with price like ram , battery power, pixcel,

# %%
# ques 1 
import pandas as pd
cs=pd.read_csv("customer_shopping_data (1).csv")
# Out:
# C:\Users\NIHARIKA\AppData\Roaming\Python\Python310\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
cs
# Out:
#       invoice_no customer_id  gender  age         category  quantity    price  \
# 0        I138884     C241288  Female   28         Clothing         5  1500.40
# 1        I317333     C111565    Male   21            Shoes         3  1800.51
# 2        I127801     C266599    Male   20         Clothing         1   300.08
# 3        I173702     C988172  Female   66            Shoes         5  3000.85
# 4        I337046     C189076  Female   53            Books         4    60.60
# ...          ...         ...     ...  ...              ...       ...      ...
# 99452    I219422     C441542  Female   45         Souvenir         5    58.65
# 99453    I325143     C569580    Male   27  Food & Beverage         2    10.46
# 99454    I824010     C103292    Male   63  Food & Beverage         2    10.46
# 99455    I702964     C800631    Male   56       Technology         4  4200.00
# 99456    I232867     C273973  Female   36         Souvenir         3    35.19
#
# ...

# %%
cs.shopping_mall.value_counts()
# Out:
# shopping_mall
# Mall of Istanbul     19943
# Kanyon               19823
# Metrocity            15011
# Metropol AVM         10161
# Istinye Park          9781
# Zorlu Center          5075
# Cevahir AVM           4991
# Forum Istanbul        4947
# Viaport Outlet        4914
# Emaar Square Mall     4811
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df.columns=['count_of_cust']

# %%
df
# Out:
#                    count_of_cust
# shopping_mall
# Mall of Istanbul           19943
# Kanyon                     19823
# Metrocity                  15011
# Metropol AVM               10161
# Istinye Park                9781
# Zorlu Center                5075
# Cevahir AVM                 4991
# Forum Istanbul              4947
# Viaport Outlet              4914
# Emaar Square Mall           4811

# %%
df=pd.DataFrame(cs.shopping_mall.value_counts())
df
# Out:
#                    count
# shopping_mall
# Mall of Istanbul   19943
# Kanyon             19823
# Metrocity          15011
# Metropol AVM       10161
# Istinye Park        9781
# Zorlu Center        5075
# Cevahir AVM         4991
# Forum Istanbul      4947
# Viaport Outlet      4914
# Emaar Square Mall   4811

# %%
plt.figure(figsize=(5,5))
plt.pie(df.count_of_cust, labels=df.index,autopct='%1.0f%%')
plt.title("no of customer in each mall")
# Out:
# Text(0.5, 1.0, 'no of customer in each mall')

# %%
# For opening a shop in mall lets compare other malls
plt.figure(figsize=(12,12))
plt.hist(cs.shopping_mall,color='plum',bins=20,edgecolor='black');
plt.xticks(rotation=45)
plt.grid()

# %%
# for above graph there are various number of malls in city among which the highest count of people or population is among mall of istambull
# so for opening the shop in the city we would choose the mall of istambul as it has great number of people interaction

# %%
plt.figure(figsize=(5,5))
plt.pie(df1.count_of_category, labels=df1.index,autopct='%1.0f%%')
plt.title("no of category in each mall")
# Out:
# Text(0.5, 1.0, 'no of category in each mall')

# %%
df1=pd.DataFrame(cs.category.value_counts())

# %%
df1.columns=['count_of_category']

# %%
df1
# Out:
#                  count_of_category
# category
# Clothing                     34487
# Cosmetics                    15097
# Food & Beverage              14776
# Toys                         10087
# Shoes                        10034
# Souvenir                      4999
# Technology                    4996
# Books                         4981

# %%
# ques 1 2nd part  ---- that indicates which category we should sell in the shop to gain more customer attention
cs.category.value_counts()
# Out:
# category
# Clothing           34487
# Cosmetics          15097
# Food & Beverage    14776
# Toys               10087
# Shoes              10034
# Souvenir            4999
# Technology          4996
# Books               4981
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12,12))
plt.hist(cs.category,color='orange',bins=20,edgecolor='black');
plt.grid()

# %%
plt.figure(figsize=(8,8))
plt.bar(df.index,df.count_of_cust,color=['red','blue','aqua','purple','green','plum','yellow','orange','pink','violet'])
plt.xticks(rotation=45)
plt.grid()

# %%
# so in clothing high rate of customer are being attracted . so according to analysis clothing category should be selled in the new shop at mall of istambul

# %%
plt.figure(figsize=(8,8))
plt.bar(df1.index,df1.count_of_category,color=['red','blue','aqua','purple','green','plum','yellow','orange','pink','violet'])
plt.xticks(rotation=45)
plt.grid()

# %%
#ques1 part 3---for searching each gender category to take which category does more shopping we use group by function
g1=cs.groupby(['category','gender'])['price'].sum()

# %%
plt.figure(figsize=(7,7))
sns.barplot(df1.index,df1.count_of_category)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[50], line 2
#       1 plt.figure(figsize=(7,7))
# ----> 2 sns.barplot(df1.index,df1.count_of_category)
#
# TypeError: barplot() takes from 0 to 1 positional arguments but 2 were given

# %%
sns.countplot(x='shopping_mall',data=cs,order=cs['shopping_mall'].value_counts(ascending=False).index)
plt.xticks(rotation=45)
plt.title('No of customer in every mall',color='orange')
# this shows the number of malls and there count where everyone visit
# most visited mall according to plot is mall of istanbull, kanyon 
# so for opening shop in mall we will look to mall of istanbull
# Out:
# Text(0.5, 1.0, 'No of customer in every mall')

# %%
sns.countplot(x='category',data=cs,order=cs['category'].value_counts(ascending=False).index)
plt.xticks(rotation=45)
plt.title('Product sold most ')
# this shows the most amount of product sold and clothing brand is the one . so for selling a product in shop we can sell clothing
# Out:
# Text(0.5, 1.0, 'Product sold most ')

# %%
sns.countplot(x='gender',data=cs,order=cs['gender'].value_counts(ascending=False).index)
plt.xticks(rotation=45)
# Out:
# (array([0, 1]), [Text(0, 0, 'Female'), Text(1, 0, 'Male')])

# %%
g1.plot(kind='bar')
plt.title('Particular gender shopping for each category')
plt.xlabel('category')
plt.ylabel('sales')
plt.legend('Gender')

# %%
sns.countplot(x='shopping_mall',data=cs,order=cs['shopping_mall'].value_counts(ascending=False).index,hue='gender')
plt.xticks(rotation=45)
plt.title('count of Male and Female in each mall',color='blue')
# Out:
# Text(0.5, 1.0, 'count of Male and Female in each mall')

# %%
# so for every category we need numerical 
sns.boxplot(x='Smoke',y='LungCap',data=lc,hue='Gender')
# Out:
# <Axes: xlabel='Smoke', ylabel='LungCap'>

# %%
import pandas as pd
lc=pd.read_csv("LungCapData.csv")

# %%
sns.boxplot(x='payment_method',y='price',data=cs,hue='gender')
# Out:
# <Axes: xlabel='payment_method', ylabel='price'>

# %%
sns.countplot(x='shopping_mall',data=cs,order=cs['shopping_mall'].value_counts(ascending=False).index,hue='category')
plt.xticks(rotation=45)
plt.title('count of Male and Female in each mall',color='blue')
# in every shopping mall count of clothing is maximun 
# count of categories in each shopping mall blue indicated clothing so they are most likely to shop only clothing
# Out:
# Text(0.5, 1.0, 'count of Male and Female in each mall')

# %%
sns.countplot(x='shopping_mall',data=cs,order=cs['shopping_mall'].value_counts(ascending=False).index,hue='payment_method')
plt.xticks(rotation=45)
plt.title('count of customer in each Shopping mall with different payment methods',color='black')
# Out:
# Text(0.5, 1.0, 'count of customer in each Shopping mall with different payment methods')

# %%
# istanbul and kanoyon
# sold item is clothes

# first see amount of sales

# %%
df2=pd.DataFrame(cs.groupby('category').price.sum().round())
df2=df2.sort_values('price',ascending=False)
df2
# Out:
#                       price
# category
# Clothing         31075685.0
# Shoes            18135337.0
# Technology       15772050.0
# Cosmetics         1848607.0
# Toys              1086705.0
# Food & Beverage    231569.0
# Books              226977.0
# Souvenir           174437.0

# %%
plt.figure(figsize=(11,11))
plt.pie(df2.price,labels=df2.index,autopct='%1.0f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x298bad63460>,
# ...
#  [Text(1.0999404899807423, 0.011441962284713472, 'Books'),
#   Text(0.13806599371834147, 1.0913009582047324, 'Clothing'),
#   Text(-1.080663533628443, 0.20534441089468955, 'Cosmetics'),
#   Text(-1.0953027616567559, 0.10154733037891198, 'Food & Beverage'),
#   Text(-0.8053998466460364, -0.7492203194138165, 'Shoes'),
#   Text(0.01934390549359644, -1.099829901994056, 'Souvenir'),
#   Text(0.7485032347167138, -0.8060663171344007, 'Technology'),
#   Text(1.0986361844766437, -0.05475887287556562, 'Toys')],
#  [Text(0.5999675399894957, 0.0062410703371164385, '0%'),
#   Text(0.07530872384636807, 0.5952550681116722, '45%'),
#   Text(-0.5894528365246052, 0.11200604230619429, '3%'),
#   Text(-0.597437869994594, 0.055389452933951984, '0%'),
#   Text(-0.4393090072614743, -0.4086656287711726, '26%'),
#   Text(0.01055122117832533, -0.5999072192694851, '0%'),
#   Text(0.408274491663662, -0.439672536618764, '23%'),
# ...

# %%
plt.figure(figsize=(6,6))
plt.pie(df2.price,labels=df2.index,autopct='%1.0f%%')
plt.title('total amount of sales of each category',color='blue')#without sorting in descending order
# Out:
# Text(0.5, 1.0, 'total amount of sales of each category')

# %%
plt.figure(figsize=(6,6))
plt.pie(df2.price[0:4],labels=df2.index[0:4],autopct='%1.0f%%')
plt.title('total amount of sales of each category for top 4',color='blue')# [0:4] tells takes first 4 indexes it shows only few first four category
# Out:
# Text(0.5, 1.0, 'total amount of sales of each category for top 4')

# %%
plt.figure(figsize=(6,6))
plt.pie(df2.price[3:7],labels=df2.index[3:7],autopct='%1.0f%%')# range from last 
plt.title('total amount of sales of each category',color='blue')
# Out:
# Text(0.5, 1.0, 'total amount of sales of each category')

# %%
plt.figure(figsize=(6,6))
plt.pie(df2.price[4::],labels=df2.index[4::],autopct='%1.0f%%')
plt.title('total amount of sales of each category',color='blue')#bottom 4
# Out:
# Text(0.5, 1.0, 'total amount of sales of each category')

# %%
plt.figure(figsize=(5,5))
plt.bar(df2.index,df2.price)
plt.xticks(rotation=45)
plt.grid()

# %%
# above y axis shows 3 , 2 but above itz is written le7 so lets convert it in number 
df2['price_in_million']=df2.price/1000000

# %%
df2# for foreingers to understand----- 10 lakh = 1 million so clothing is 31 million
# Out:
#                       price  price_in_million
# category
# Clothing         31075685.0         31.075685
# Shoes            18135337.0         18.135337
# Technology       15772050.0         15.772050
# Cosmetics         1848607.0          1.848607
# Toys              1086705.0          1.086705
# Food & Beverage    231569.0          0.231569
# Books              226977.0          0.226977
# Souvenir           174437.0          0.174437

# %%
plt.figure(figsize=(5,5))
plt.bar(df2.index,df2.price_in_million)
plt.title('sales in million USD',color='purple')
plt.xticks(rotation=45)
plt.grid()

# %%
# will choose mall of istan bull to cjech what is ther
istanbull=cs[cs.shopping_mall=='Mall of Istanbul']
istanbull.head()
# Out:
#    invoice_no customer_id  gender  age   category  quantity    price  \
# 7     I293112     C176086  Female   32   Clothing         2   600.16
# 26    I196704     C289625  Female   25  Cosmetics         5   203.30
# 30    I161949     C159164  Female   66       Toys         3   107.52
# 46    I267193     C317818  Female   19  Cosmetics         3   121.98
# 60    I133061     C336576    Male   64   Clothing         5  1500.40
#
#    payment_method invoice_date     shopping_mall
# 7     Credit Card   13/01/2021  Mall of Istanbul
# 26    Credit Card   20/04/2022  Mall of Istanbul
# 30     Debit Card     4/7/2022  Mall of Istanbul
# 46    Credit Card    12/1/2023  Mall of Istanbul
# 60    Credit Card     9/6/2022  Mall of Istanbul

# %%
istanbull.shape
# Out:
# (19943, 10)

# %%
sns.boxplot(x='category',y='price',data=istanbull)
plt.xticks(rotation=45)
plt.title('price range for each category',color='blue')# price range for technology in istanbull is high
# Out:
# Text(0.5, 1.0, 'price range for each category')

# %%
df4=cs[(cs.age>=18) & (cs.age<=30)]
df4
# Out:
#       invoice_no customer_id  gender  age         category  quantity    price  \
# 0        I138884     C241288  Female   28         Clothing         5  1500.40
# 1        I317333     C111565    Male   21            Shoes         3  1800.51
# 2        I127801     C266599    Male   20         Clothing         1   300.08
# 5        I227836     C657758  Female   28         Clothing         5  1500.40
# 11       I139207     C191708  Female   29            Books         1    15.15
# ...          ...         ...     ...  ...              ...       ...      ...
# 99431    I191779     C131280    Male   26        Cosmetics         4   162.64
# 99433    I403904     C142643    Male   28             Toys         1    35.84
# 99444    I131678     C119287    Male   24             Toys         1    35.84
# 99450    I170504     C226974  Female   28            Books         1    15.15
# 99453    I325143     C569580    Male   27  Food & Beverage         2    10.46
#
# ...

# %%
cs.age.describe()
# Out:
# count    99457.000000
# mean        43.427089
# std         14.990054
# min         18.000000
# 25%         30.000000
# 50%         43.000000
# 75%         56.000000
# max         69.000000
# Name: age, dtype: float64

# %%
g1
# Out:
# category         gender
# Books            Female      132956.40
#                  Male         94020.90
# Clothing         Female    18616663.12
#                  Male      12459021.52
# Cosmetics        Female     1108432.26
#                  Male        740174.64
# Food & Beverage  Female      137873.26
#                  Male         93695.45
# Shoes            Female    10746644.02
#                  Male       7388692.87
# Souvenir         Female      105288.48
#                  Male         69148.35
# Technology       Female     9425850.00
#                  Male       6346200.00
# Toys             Female      658094.08
#                  Male        428610.56
# Name: price, dtype: float64

# %%
# from above we we can say in clothing category female have more preference to it 
# so for opening shop in instambul mall for clothing product we need to target females clothing section more

# %%
df3=pd.DataFrame(cs.payment_method.value_counts())
df3.columns=['count_payments']

# %%
df3
# Out:
#                 count_payments
# payment_method
# Cash                     44447
# Credit Card              34931
# Debit Card               20079

# %%
plt.figure(figsize=(6,6))
plt.pie(df3.count_payments,labels=df3.index,autopct='%1.0f%%')
plt.title('total amount of sales of each category',color='blue')
# Out:
# Text(0.5, 1.0, 'total amount of sales of each category')

# %%
# mall istanbull and kanyon
# prffered category is clothing according to count and amount and total sales 
# female has more approachable count wise 
# total amount of shopping is more foir female or male ??????---female
# cash is mostly used 
# check the purchasing power of people in age group of less than or equal to 30and compare with those who are 40-50

# %%
df5=pd.DataFrame(cs.groupby('gender').price.sum().round()/1000000)

# %%
df5
# Out:
#             price
# gender
# Female  40.931802
# Male    27.619564

# %%
# female is spending

# %%
df5=pd.DataFrame(cs.groupby('gender').age.sum().round())
df5
# Out:
#             age
# gender
# Female  2584702
# Male    1734426

# %%
df6=pd.DataFrame(cs[cs.age<=30])
df6
# Out:
#       invoice_no customer_id  gender  age         category  quantity    price  \
# 0        I138884     C241288  Female   28         Clothing         5  1500.40
# 1        I317333     C111565    Male   21            Shoes         3  1800.51
# 2        I127801     C266599    Male   20         Clothing         1   300.08
# 5        I227836     C657758  Female   28         Clothing         5  1500.40
# 11       I139207     C191708  Female   29            Books         1    15.15
# ...          ...         ...     ...  ...              ...       ...      ...
# 99431    I191779     C131280    Male   26        Cosmetics         4   162.64
# 99433    I403904     C142643    Male   28             Toys         1    35.84
# 99444    I131678     C119287    Male   24             Toys         1    35.84
# 99450    I170504     C226974  Female   28            Books         1    15.15
# 99453    I325143     C569580    Male   27  Food & Beverage         2    10.46
#
# ...

# %%
df7=cs[(cs.age>30) & (cs.age<=50)]
df7
# Out:
#       invoice_no customer_id  gender  age         category  quantity   price  \
# 6        I121056     C151197  Female   49        Cosmetics         1   40.66
# 7        I293112     C176086  Female   32         Clothing         2  600.16
# 10       I306368     C240286  Female   36  Food & Beverage         2   10.46
# 17       I195744     C330667  Female   42  Food & Beverage         3   15.69
# 18       I993048     C218149  Female   46         Clothing         2  600.16
# ...          ...         ...     ...  ...              ...       ...     ...
# 99446    I327966     C107209  Female   32  Food & Beverage         1    5.23
# 99447    I281214     C288090  Female   37             Toys         3  107.52
# 99451    I675411     C513603    Male   50             Toys         5  179.20
# 99452    I219422     C441542  Female   45         Souvenir         5   58.65
# 99456    I232867     C273973  Female   36         Souvenir         3   35.19
#
# ...

# %%
df1=cs.groupby("gender").age.mean()
df1
# Out:
# gender
# Female    43.453515
# Male      43.387767
# Name: age, dtype: float64

# %%
#que1 part4---what price range to keep
plt.figure(figsize=(12,12))
plt.hist(cs.price,color='plum',bins=20,edgecolor='black');
plt.grid()

# %%
cs.price.value_counts()
# Out:
# price
# 600.16     6950
# 1500.40    6940
# 900.24     6907
# 1200.32    6849
# 300.08     6841
# 121.98     3072
# 203.30     3055
# 162.64     3010
# 5.23       3002
# 15.69      2992
# 26.15      2989
# 40.66      2986
# 81.32      2974
# 10.46      2909
# 20.92      2884
# 107.52     2082
# 143.36     2076
# 1200.34    2045
# 2400.68    2022
# 3000.85    2013
# 1800.51    2010
# 35.84      2000
# 179.20     1971
# 71.68      1958
# 600.17     1944
# 35.19      1077
# 75.75      1029
# 11.73      1024
# 3150.00    1009
# 30.30      1008
# 4200.00    1001
# 5250.00    1001
# 2100.00    1000
# 45.45      1000
# 58.65       992
# 15.15       985
# 1050.00     985
# 23.46       984
# 60.60       959
# 46.92       922
# Name: count, dtype: int64

# %%
# from above plot it sugggest that in between interval of 0-250 or 0 to 300 the most price and max number of people are shopping the things

# %%
# que1 --part5---payment method
cs.payment_method.value_counts()
# Out:
# payment_method
# Cash           44447
# Credit Card    34931
# Debit Card     20079
# Name: count, dtype: int64

# %%
plt.hist(cs.payment_method,color='aqua',bins=20,edgecolor='black');

# %%
# according to above the data depicts things to have cash payment method to be used mostly ... so to be used method in shop is cash payment method it is prefered by population

# %%
######## que 2 ADDISASSS

# %%
# addidas
# which prod is having max nd min sales 
#prod and operating profit
#state and sales
#state and product

# %%
ad=pd.read_csv("AdidasUSSalesDatasets1.csv")

# %%
ad
# Out:
#      Unnamed: 0     Retailer  Retailer ID Invoice Date     Region  \
# 0           NaN  Foot Locker      1185732   01-01-2020  Northeast
# 1           NaN  Foot Locker      1185732   02-01-2020  Northeast
# 2             s  Foot Locker      1185732   03-01-2020  Northeast
# 3           NaN  Foot Locker      1185732   04-01-2020  Northeast
# 4           NaN  Foot Locker      1185732   05-01-2020  Northeast
# ...         ...          ...          ...          ...        ...
# 9643        NaN  Foot Locker      1185732   24-01-2021  Northeast
# 9644        NaN  Foot Locker      1185732   24-01-2021  Northeast
# 9645        NaN  Foot Locker      1185732   22-02-2021  Northeast
# 9646        NaN  Foot Locker      1185732   22-02-2021  Northeast
# 9647        NaN  Foot Locker      1185732   22-02-2021  Northeast
#
#               State        City                    Product Price per Unit  \
# 0          New York    New York      Men's Street Footwear        $50.00
# ...

# %%
# Ques2 --part1--which prod is having max nd min sales

# %%
products=ad['Product']
sales=ad['Total_Sales']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 products=ad['Product']
#       2 sales=ad['Total_Sales']
#
# NameError: name 'ad' is not defined

# %%
plt.pie(ad['Total_Sales'],labels=ad['Product'],autopct='%1.0f%%')
plt.title('Product sales')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 plt.pie(ad['Total_Sales'],labels=ad['Product'],autopct='%1.0f%%')
#       2 plt.title('Product sales')
#
# File ~\anaconda3\lib\site-packages\matplotlib\pyplot.py:2772, in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, hatch, data)
#    2765 @_copy_docstring_and_deprecators(Axes.pie)
#    2766 def pie(
#    2767         x, explode=None, labels=None, colors=None, autopct=None,
#    (...)
#    2770         textprops=None, center=(0, 0), frame=False,
#    2771         rotatelabels=False, *, normalize=True, hatch=None, data=None):
# -> 2772     return gca().pie(
#    2773         x, explode=explode, labels=labels, colors=colors,
# ...

# %%
# que2 part--2
# state vs sales
states=ad['State']
sales=ad['Total_Sales']

# %%
ad=ad.rename(columns={'Total Sales':'Total_Sales'})

# %%
ad.head()
# Out:
#   Unnamed: 0     Retailer  Retailer ID Invoice Date     Region     State  \
# 0        NaN  Foot Locker      1185732   01-01-2020  Northeast  New York
# 1        NaN  Foot Locker      1185732   02-01-2020  Northeast  New York
# 2          s  Foot Locker      1185732   03-01-2020  Northeast  New York
# 3        NaN  Foot Locker      1185732   04-01-2020  Northeast  New York
# 4        NaN  Foot Locker      1185732   05-01-2020  Northeast  New York
#
#        City                    Product Price per Unit Units Sold Total_Sales  \
# 0  New York      Men's Street Footwear        $50.00       1,200  $6,00,000
# 1  New York    Men's Athletic Footwear        $50.00       1,000  $5,00,000
# 2  New York    Women's Street Footwear        $40.00       1,000  $4,00,000
# 3  New York  Women's Athletic Footwear        $45.00         850  $3,82,500
# 4  New York              Men's Apparel        $60.00         900  $5,40,000
#
#   Operating Profit Operating Margin Sales Method
# ...

# %%
plt.figure(figsize=(10,8))
plt.barh(ad.State,ad.Total_Sales)
plt.xlabel('State')
plt.ylabel('Total sales')
plt.title('Total sales of each state')
plt.grid()

# %%
states=ad['State']
sales=ad['Total_Sales']
plt.bar(ad.State,ad.Total_Sales,color='purple')

# %%
g2=ad.groupby(['Product','State'])['Total_Sales'].sum()
g2.plot(kind='bar')
plt.title('Particular gender shopping for each category')
plt.xlabel('category')
plt.ylabel('sales')
plt.legend('Gender')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 g2=ad.groupby(['Product','State'])['Total_Sales'].sum()
# ----> 2 g2.plot(kind='bar')
#       3 plt.title('Particular gender shopping for each category')
#       4 plt.xlabel('category')
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\plotting\_core.py:1030, in PlotAccessor.__call__(self, *args, **kwargs)
#    1027             label_name = label_kw or data.columns
#    1028             data.columns = label_name
# -> 1030 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
# ...

# %%
# trainrf
# data set of mobile
# compare all features  with price like ram , battery power, pixcel,

# %%
#ques 3-- part one 
tt=pd.read_csv("train.csv")

# %%
tt.head(15)
# Out:
#     battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0             842     0          2.2         0   1       0           7    0.6
# 1            1021     1          0.5         1   0       1          53    0.7
# 2             563     1          0.5         1   2       1          41    0.9
# 3             615     1          2.5         0   0       0          10    0.8
# 4            1821     1          1.2         0  13       1          44    0.6
# 5            1859     0          0.5         1   3       0          22    0.7
# 6            1821     0          1.7         0   4       1          10    0.8
# 7            1954     0          0.5         1   0       0          24    0.8
# 8            1445     1          0.5         0   0       0          53    0.7
# 9             509     1          0.6         1   2       1           9    0.1
# 10            769     1          2.9         1   0       0           9    0.1
# ...

# %%
tt.columns
# Out:
# Index(['battery_power', 'blue', 'clock_speed', 'dual_sim', 'fc', 'four_g',
#        'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc', 'px_height',
#        'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g',
#        'touch_screen', 'wifi', 'price_range'],
#       dtype='object')

# %%
# batttery vs price
sns.pointplot(x ='price_range', y ='battery_power',data=tt)
# Out:
# <Axes: xlabel='price_range', ylabel='battery_power'>

# %%
# for each increasing battery power there is increase in the price range

# %%
# dual sim vs price
sns.pointplot(x ='dual_sim', y ='price_range',data=tt)
# Out:
# <Axes: xlabel='dual_sim', ylabel='price_range'>

# %%
# those who have dual sim there price is low as compared to those who have dual sim .
# this mean for each mobile that contain dual sim will have the price range higher

# %%
# clock speed vs price 
sns.lineplot(x ='clock_speed', y ='price_range',data=tt)
# Out:
# C:\Users\NIHARIKA\anaconda3\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\NIHARIKA\anaconda3\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='clock_speed', ylabel='price_range'>

# %%
# x axis shows speed of mobile clock device and y depicts price range it shows positive correlation between clock speed and price because when speed in range 1-1.5 is high the price increases

# %%
# four g vs price
sns.pointplot(x ='four_g', y ='price_range',data=tt)
# Out:
# <Axes: xlabel='four_g', ylabel='price_range'>

# %%
#those who dont have 4g feature there mobile price range is lower than those who have 4g feature

# %%
#int_memory vs price 
plt.figure(figsize=(10,8))
sns.pointplot(x='int_memory',y='price_range',data=tt)
# Out:
# <Axes: xlabel='int_memory', ylabel='price_range'>

# %%
sns.boxplot(x='int_memory',y='price_range',data=tt)
# Out:
# <Axes: xlabel='int_memory', ylabel='price_range'>

# %%
# may be we can depict that when the int memory increases the price range increases

# %%
sns.lineplot(y ='price_range', x ='int_memory',data=tt)
# Out:
# C:\Users\NIHARIKA\anaconda3\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\NIHARIKA\anaconda3\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='int_memory', ylabel='price_range'>

# %%
sns.jointplot(x ='price_range', y ='ram',data=tt)
# Out:
# C:\Users\NIHARIKA\anaconda3\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\NIHARIKA\anaconda3\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# when the size of ram increases the price range increases

# %%
plt.figure(figsize=(5,5))
plt.hist(tt.mobile_wt,color='plum',bins=15,edgecolor='black');
plt.ylabel="count"
plt.xlabel='mobile weight'
plt.grid()

# %%
df1=pd.DataFrame(tt.groupby('price_range').ram.mean().round())
df1
# Out:
#                 ram
# price_range
# 0             785.0
# 1            1679.0
# 2            2583.0
# 3            3449.0

# %%
df1.index=['low','med','high','very high']
plt.pie(df1.ram,label=df1.index)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 df1.index=['low','med','high','very high']
# ----> 2 plt.pie(df1.ram,label=df1.index)
#
# TypeError: pie() got an unexpected keyword argument 'label'

# %%
# bar 
plt.bar(df1.index,df1.ram)
# Out:
# <BarContainer object of 4 artists>

# %%
sns.barplot(df1.index,df1.ram);
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 sns.barplot(df1.index,df1.ram)
#
# TypeError: barplot() takes from 0 to 1 positional arguments but 2 were given

# %%
#property 
abcd=pd.DataFrame(pp.isnull().sum()[pp.isnull().sum()>0])

abcd.columns=["null_count"]
abcd
# Out:
#                        null_count
# Lot_Extent                    259
# Lane_Type                    1368
# Brick_Veneer_Type             871
# Brick_Veneer_Area               8
# Basement_Height                37
# Basement_Condition             37
# Exposure_Level                 38
# BsmtFinType1                   37
# BsmtFinType2                   38
# Electrical_System               1
# Fireplace_Quality             689
# Garage                         81
# Garage_Built_Year              81
# Garage_Finish_Year             81
# Garage_Quality                 81
# Garage_Condition               81
# Pool_Quality                 1452
# Fence_Quality                1178
# Miscellaneous_Feature        1405

# %%
abcd=abcd.sort_values('null_count',ascending=False)
abcd
# Out:
#                        null_count
# Pool_Quality                 1452
# Miscellaneous_Feature        1405
# Lane_Type                    1368
# Fence_Quality                1178
# Brick_Veneer_Type             871
# Fireplace_Quality             689
# Lot_Extent                    259
# Garage                         81
# Garage_Built_Year              81
# Garage_Finish_Year             81
# Garage_Quality                 81
# Garage_Condition               81
# BsmtFinType2                   38
# Exposure_Level                 38
# BsmtFinType1                   37
# Basement_Condition             37
# Basement_Height                37
# Brick_Veneer_Area               8
# Electrical_System               1

# %%
pp.isnull().sum()*100/pp.shape[0]
# Out:
# Id                 0.000000
# Building_Class     0.000000
# Zoning_Class       0.000000
# Lot_Extent        17.751885
# Lot_Size           0.000000
#                     ...
# Month_Sold         0.000000
# Year_Sold          0.000000
# Sale_Type          0.000000
# Sale_Condition     0.000000
# Sale_Price         0.000000
# Length: 81, dtype: float64

# %%
abcd.null_count=abcd.null_count*100/pp.shape[0]

# %%
# x axis name y axis is percentage 
pp=pd.read_csv('Property_Price_Train.csv')

# %%
plt.figure(figsize=(10,8))
sns.barplot(x='index',y='null_count',data=abcd,kind='count')
plt.xsticks(rotation=45);
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[61], line 2
#       1 plt.figure(figsize=(10,8))
# ----> 2 sns.barplot(x='index',y='null_count',data=abcd,kind='count')
#       3 plt.xsticks(rotation=45)
#
# File ~\anaconda3\lib\site-packages\seaborn\categorical.py:2755, in barplot(data, x, y, hue, order, hue_order, estimator, errorbar, n_boot, units, seed, orient, color, palette, saturation, width, errcolor, errwidth, capsize, dodge, ci, ax, **kwargs)
#    2752 if estimator is len:
#    2753     estimator = "size"
# -> 2755 plotter = _BarPlotter(x, y, hue, data, order, hue_order,
#    2756                       estimator, errorbar, n_boot, units, seed,
#    2757                       orient, color, palette, saturation,
#    2758                       width, errcolor, errwidth, capsize, dodge)
#    2760 if ax is None:
#    2761     ax = plt.gca()
#
# ...

# %%
months=['jan','feb','mar','apr','may','jun','july','aug','sep']
profit=[500,700,-100,-150,300,450,550,400,430]

# %%
plt.bar(months,profit)
plt.xlabel('months')
plt.ylabel('profit in cr')
plt.xticks(rotation=45);
# draw line which is paralell to x ---y intercept
plt.axhline(y=0,color='red')
#plt.axvline(x=0,color='red')

# %%
#aim to have different color for profit and 
# mar n apr in black rest in green
profit=[500,700,-100,-150,300,450,550,400,430]
col_list=[]
for i in profit:
    if i<0 :
        col_list.append('black')
    else:
        col_list.append('green')

# %%
col_list
# Out:
# ['green',
#  'green',
#  'black',
#  'black',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green']

# %%
plt.bar(months,profit,color=col_list)
plt.xlabel('months')
plt.ylabel('profit in cr')
plt.xticks(rotation=45);
# draw line which is paralell to x ---y intercept
plt.axhline(y=0,color='red')
#plt.axvline(x=0,color='red')
